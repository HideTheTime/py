# %%
import numpy as np
import pandas as pd 
data = pd.read_csv('iris_data.csv')
data.head()
# Out:
#    sepal length  sepal width  petal length  petal width       target  label
# 0           5.1          3.5           1.4          0.2  Iris-setosa      0
# 1           4.9          3.0           1.4          0.2  Iris-setosa      0
# 2           4.7          3.2           1.3          0.2  Iris-setosa      0
# 3           4.6          3.1           1.5          0.2  Iris-setosa      0
# 4           5.0          3.6           1.4          0.2  Iris-setosa      0

# %%
x = data.drop(['target','label'],axis=1)
y = data.loc[:,'label']
x.head()
y.head()
print(x.shape,y.shape)
# Out:
# (150, 4) (150,)

# %%
from sklearn import tree
dc_tree = tree.DecisionTreeClassifier(criterion='entropy',min_samples_leaf=5)
dc_tree.fit(x,y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=5, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
y_predict =dc_tree.predict(x)
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y,y_predict)
print(accuracy)
# Out:
# 0.9733333333333334

# %%
from matplotlib import pyplot as plt 
fig = plt.figure(figsize=(15,10))
tree.plot_tree(dc_tree,filled='True',feature_names=['SepalLength','SepalWidth','PetalLength','PetalWidth'],class_names=['setosa','versicolor','virginica'])
# Out:
# [Text(372.0, 489.24, 'PetalLength <= 2.45\nentropy = 1.585\nsamples = 150\nvalue = [50, 50, 50]\nclass = setosa'),
#  Text(279.0, 380.52000000000004, 'entropy = 0.0\nsamples = 50\nvalue = [50, 0, 0]\nclass = setosa'),
#  Text(465.0, 380.52000000000004, 'PetalWidth <= 1.75\nentropy = 1.0\nsamples = 100\nvalue = [0, 50, 50]\nclass = versicolor'),
#  Text(279.0, 271.8, 'PetalLength <= 4.95\nentropy = 0.445\nsamples = 54\nvalue = [0, 49, 5]\nclass = versicolor'),
#  Text(186.0, 163.08000000000004, 'SepalLength <= 5.15\nentropy = 0.146\nsamples = 48\nvalue = [0, 47, 1]\nclass = versicolor'),
#  Text(93.0, 54.360000000000014, 'entropy = 0.722\nsamples = 5\nvalue = [0, 4, 1]\nclass = versicolor'),
#  Text(279.0, 54.360000000000014, 'entropy = 0.0\nsamples = 43\nvalue = [0, 43, 0]\nclass = versicolor'),
#  Text(372.0, 163.08000000000004, 'entropy = 0.918\nsamples = 6\nvalue = [0, 2, 4]\nclass = virginica'),
#  Text(651.0, 271.8, 'PetalLength <= 4.95\nentropy = 0.151\nsamples = 46\nvalue = [0, 1, 45]\nclass = virginica'),
#  Text(558.0, 163.08000000000004, 'entropy = 0.65\nsamples = 6\nvalue = [0, 1, 5]\nclass = virginica'),
#  Text(744.0, 163.08000000000004, 'entropy = 0.0\nsamples = 40\nvalue = [0, 0, 40]\nclass = virginica')]

# %%
dc_tree = tree.DecisionTreeClassifier(criterion='entropy',min_samples_leaf=1)
dc_tree.fit(x,y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
from matplotlib import pyplot as plt 
fig = plt.figure(figsize=(15,15))
tree.plot_tree(dc_tree,filled='True',feature_names=['SepalLength','SepalWidth','PetalLength','PetalWidth'],class_names=['setosa','versicolor','virginica'])
# Out:
# [Text(418.5, 747.4499999999999, 'PetalLength <= 2.45\nentropy = 1.585\nsamples = 150\nvalue = [50, 50, 50]\nclass = setosa'),
#  Text(354.11538461538464, 611.55, 'entropy = 0.0\nsamples = 50\nvalue = [50, 0, 0]\nclass = setosa'),
#  Text(482.8846153846154, 611.55, 'PetalWidth <= 1.75\nentropy = 1.0\nsamples = 100\nvalue = [0, 50, 50]\nclass = versicolor'),
#  Text(257.53846153846155, 475.65, 'PetalLength <= 4.95\nentropy = 0.445\nsamples = 54\nvalue = [0, 49, 5]\nclass = versicolor'),
#  Text(128.76923076923077, 339.74999999999994, 'PetalWidth <= 1.65\nentropy = 0.146\nsamples = 48\nvalue = [0, 47, 1]\nclass = versicolor'),
#  Text(64.38461538461539, 203.8499999999999, 'entropy = 0.0\nsamples = 47\nvalue = [0, 47, 0]\nclass = versicolor'),
#  Text(193.15384615384616, 203.8499999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(386.3076923076923, 339.74999999999994, 'PetalWidth <= 1.55\nentropy = 0.918\nsamples = 6\nvalue = [0, 2, 4]\nclass = virginica'),
#  Text(321.9230769230769, 203.8499999999999, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3]\nclass = virginica'),
#  Text(450.69230769230774, 203.8499999999999, 'PetalLength <= 5.45\nentropy = 0.918\nsamples = 3\nvalue = [0, 2, 1]\nclass = versicolor'),
#  Text(386.3076923076923, 67.94999999999993, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = versicolor'),
#  Text(515.0769230769231, 67.94999999999993, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(708.2307692307693, 475.65, 'PetalLength <= 4.85\nentropy = 0.151\nsamples = 46\nvalue = [0, 1, 45]\nclass = virginica'),
#  Text(643.8461538461538, 339.74999999999994, 'SepalLength <= 5.95\nentropy = 0.918\nsamples = 3\nvalue = [0, 1, 2]\nclass = virginica'),
#  Text(579.4615384615385, 203.8499999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = versicolor'),
#  Text(708.2307692307693, 203.8499999999999, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = virginica'),
#  Text(772.6153846153846, 339.74999999999994, 'entropy = 0.0\nsamples = 43\nvalue = [0, 0, 43]\nclass = virginica')]
